# %% [markdown]
# <a href="https://colab.research.google.com/github/Udaybabubojja/machine-learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([18,19,20,42])
print(s)
s=pd.Series(["apple", "mango", "banana"])
print(s)
# Out:
# 0    18
# 1    19
# 2    20
# 3    42
# dtype: int64
# 0     apple
# 1     mango
# 2    banana
# dtype: object

# %%
n=np.array(["apple", "mango", "banana"])
s2=pd.Series(n)
print(s2)
# Out:
# 0     apple
# 1     mango
# 2    banana
# dtype: object

# %%
d1=pd.DataFrame({"name":["dilli","vikram","rolex"], "age":[28,54,32]})
print(d1)
# Out:
#      name  age
# 0   dilli   28
# 1  vikram   54
# 2   rolex   32

# %%
items = [['Phone', 2000], ['TV', 1500], ['Radio', 800]]
df3 = pd.DataFrame(items, columns=["devices", "price"])
print(df3)
df3.describe()
# Out:
#   devices  price
# 0   Phone   2000
# 1      TV   1500
# 2   Radio    800
#              price
# count     3.000000
# mean   1433.333333
# std     602.771377
# min     800.000000
# 25%    1150.000000
# 50%    1500.000000
# 75%    1750.000000
# max    2000.000000

# %%
data = pd.read_csv('/cars (1).csv')
data
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...

# %%
data.head(3)
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
#
#   Engine Information.Transmission  Fuel Information.City mpg  \
# 0  6 Speed Automatic Select Shift                         18
# ...

# %%
data.tail(2)
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline              Engine Information.Engine Type  \
# 5074             Rear-wheel drive  BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075             Rear-wheel drive  BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 5074                       True                                           6
# 5075                       True                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# ...

# %%
data['Dimensions.Width']
# Out:
# 0       202
# 1       202
# 2       202
# 3       202
# 4       202
#        ...
# 5071    201
# 5072    108
# 5073    108
# 5074    110
# 5075    110
# Name: Dimensions.Width, Length: 5076, dtype: int64

# %%
data['Engine Information.Driveline']
# Out:
# 0         All-wheel drive
# 1       Front-wheel drive
# 2       Front-wheel drive
# 3         All-wheel drive
# 4         All-wheel drive
#               ...
# 5071    Front-wheel drive
# 5072      All-wheel drive
# 5073      All-wheel drive
# 5074     Rear-wheel drive
# 5075     Rear-wheel drive
# Name: Engine Information.Driveline, Length: 5076, dtype: object

# %%
data.loc[:,['Engine Information.Driveline', 'Dimensions.Width']]
# Out:
#      Engine Information.Driveline  Dimensions.Width
# 0                 All-wheel drive               202
# 1               Front-wheel drive               202
# 2               Front-wheel drive               202
# 3                 All-wheel drive               202
# 4                 All-wheel drive               202
# ...                           ...               ...
# 5071            Front-wheel drive               201
# 5072              All-wheel drive               108
# 5073              All-wheel drive               108
# 5074             Rear-wheel drive               110
# 5075             Rear-wheel drive               110
#
# [5076 rows x 2 columns]

# %%
data.loc[[0,49,7,18],['Identification.Year']]
# Out:
#     Identification.Year
# 0                  2009
# 49                 2012
# 7                  2009
# 18                 2012

# %%
d1={
    's-id':[1,2,3,4],
    "s-name":["deepak","john","alex","arvind"]
}
d2={
    's-id':[1,6,3,8],
    "s-name":["deepak","john","alex","arvind"]
}
df1=pd.DataFrame(d1)
df2=pd.DataFrame(d2)
print(df1)
print(df2)
# Out:
#    s-id  s-name
# 0     1  deepak
# 1     2    john
# 2     3    alex
# 3     4  arvind
#    s-id  s-name
# 0     1  deepak
# 1     6    john
# 2     3    alex
# 3     8  arvind

# %%
print(pd.merge(df1, df2, on='s-id'))
# Out:
#    s-id s-name_x s-name_y
# 0     1   deepak   deepak
# 1     3     alex     alex

# %%
print(pd.concat([df1, df2]))
# Out:
#    s-id  s-name
# 0     1  deepak
# 1     2    john
# 2     3    alex
# 3     4  arvind
# 0     5  deepak
# 1     6    john
# 2     7    alex
# 3     8  arvind

# %%
data = {
    'Name': ['John', 'Alice', 'Joseph', 'Alex'],
    'English': [64, 78, 68, 58],
    'Maths': [76, 54, 72, 64]
}

df = pd.DataFrame(data)
df.describe()
# Out:
#          English      Maths
# count   4.000000   4.000000
# mean   67.000000  66.500000
# std     8.406347   9.712535
# min    58.000000  54.000000
# 25%    62.500000  61.500000
# 50%    66.000000  68.000000
# 75%    70.500000  73.000000
# max    78.000000  76.000000

# %%
raw = {
    'Name': ['John', 'John', 'Grace', 'Grace', 'Benjamin', 'Benjamin', 'Benjamin',
        'Benjamin', 'John', 'Alex', 'Alex', 'Alex'],
    'Position': [2, 1, 1, 4, 2, 4, 3, 1, 3, 2, 4, 3],
    'Year': [2009, 2010, 2009, 2010, 2010, 2010, 2011, 2012, 2011, 2013, 2013, 2012],
    'Marks':[408, 398, 422, 376, 401, 380, 396, 388, 356, 402, 368, 378]
}
df3 = pd.DataFrame(raw)
group = df3.groupby('Year')
